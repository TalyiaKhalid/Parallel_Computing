# %% [markdown]
# ## Sequential Version of the Code

# %%
# Import the necessary libraries
import os
import cv2
import numpy as np
import time

# %%
# Shared variables
processed_image_count = 0 
row_processed = 0

# %%
# Method to filter on images
def custom_filter_operation(image):

    global row_processed

    Start_time = time.time()
    # Applying Guassian Blur
    blurred_image = cv2.GaussianBlur(image, (3,3), 0)
    print(f"Time taken to apply Gaussian Blur to an image: {time.time() - Start_time}s")
        
    Start_time = time.time()
    # Computing the elevation map using Sobel operator for edge detection
    sobel_x = cv2.Sobel(blurred_image, cv2.CV_64F, 1, 0, ksize=3)
    sobel_y = cv2.Sobel(blurred_image, cv2.CV_64F, 0, 1, ksize=3)
        
    # Combining the gradients to obtain the magnitude of the gradient
    magnitude_gradient = cv2.magnitude(sobel_x, sobel_y)
    print(f"Time taken to apply Sobel filter to an image: {time.time() - Start_time}s")
    
    Start_time = time.time()
    # Normalizing the image to a range between 0 and 1 (floating-point operations)
    image = magnitude_gradient.astype(np.float32) / 255.0
    print(f"Time taken to normalize the 1 image: {time.time() - Start_time}s")

    # Getting the dimensions of the image
    height, width = image.shape

    # Creating an output image initialized to zero
    output_image = np.zeros((height, width), dtype=np.float32)

    # Custom filter (2D array) for processing
    filter_kernel = np.array([[0.1, 0.2, 0.1],
                              [0.2, 0.1, 0.2],
                              [0.1, 0.2, 0.1],], dtype=np.float32)
    filter_size = filter_kernel.shape[0]

    # Nested loops to apply the filter to the image (floating-point operation)
    Start_time = time.time()
    for i in range(height):
        for j in range(width):
            # Accumulating the weighted sum for the filter
            weighted_sum = 0.0
            for k in range(filter_size):
                for l in range(filter_size):
                    # Calculating the position in the original image
                    row = i + k - filter_size // 2
                    col = j + l - filter_size // 2
                    
                    # Checking if indices are within bounds (Conditional loop)
                    if 0 <= row < height and 0 <= col < width:
                        weighted_sum += image[row, col] * filter_kernel[k, l]

            # Updating the rows processed             
            row_processed += 1

            # Setting the pixel value in the output image 
            output_image[i, j] = weighted_sum

    print(f"Time taken to apply filter to 1 image (Nested Loop): {time.time() - Start_time}s")

    Start_time = time.time()    
    # Clipping the output to stay in the range [0, 1]
    output_image = np.clip(output_image, 0.0, 1.0)
    print(f"Time taken to Clip the output to stay in the range [0, 1]: {time.time() - Start_time}s")

    Start_time = time.time()
    # Converting the processed image back to 8-bit (0-255)
    processed_image = (output_image * 255).astype(np.uint8)
    print(f"Time taken to Convert the image back to 8-bit (0-255): {time.time() - Start_time}s")

    return processed_image

# %%
# Folder containing the images
input_folder = 'cars'  # Replace with the path to your folder
output_folder = 'cars_filtered'  # Replace with the path to save filtered images

# Creating the output folder if it doesn't exist
os.makedirs(output_folder, exist_ok=True)

# %%
Start_time_final = time.time()

# Looping through all the files in the folder
for filename in os.listdir(input_folder):
    if filename.endswith(('.jpg', '.jpeg', '.png', '.bmp')):  # Checking for image file types
        
        global processed_image_count

        # Reading the image in grayscale
        image_path = os.path.join(input_folder, filename)
        image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
        
        if image is None:
            print(f"Could not open or find the image: {image_path}")

        # Applying the custom filter operation
        Start_time = time.time()
        filtered_image = custom_filter_operation(image)
        processing_time = time.time() - Start_time
        print(f"Total Time taken to apply custom filter to the image: {processing_time}s")

        # Updating images processed 
        processed_image_count += 1

        # Saving the processed image to the output folder
        output_path = os.path.join(output_folder, f'filtered_{filename}')
        cv2.imwrite(output_path, filtered_image)

        print(f'Processed and saved: {output_path}')
        print("\n")
        
# Printing final values        
print(f"Total number of processed images: {processed_image_count}")
print(f"Total number of prcoessed rows: {row_processed}")        
print(f"Total time taken by the execution of this code sequentially for all images: {time.time() - Start_time_final}s")
# Out:
# Time taken to apply Gaussian Blur to an image: 0.0010068416595458984s
# Time taken to apply Sobel filter to an image: 0.003005504608154297s
# Time taken to normalize the 1 image: 0.0005090236663818359s
# Time taken to apply filter to 1 image (Nested Loop): 1.7924039363861084s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0005021095275878906s
# Time taken to Convert the image back to 8-bit (0-255): 0.0004978179931640625s
# Total Time taken to apply custom filter to the image: 1.7994296550750732s
# Processed and saved: cars_filtered\filtered_carsgraz_001.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.002506256103515625s
# Time taken to normalize the 1 image: 0.0009999275207519531s
# Time taken to apply filter to 1 image (Nested Loop): 1.8040239810943604s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0004982948303222656s
# Time taken to Convert the image back to 8-bit (0-255): 0.0s
# Total Time taken to apply custom filter to the image: 1.8085272312164307s
# Processed and saved: cars_filtered\filtered_carsgraz_002.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.001999378204345703s
# Time taken to normalize the 1 image: 0.0004999637603759766s
# Time taken to apply filter to 1 image (Nested Loop): 1.8080565929412842s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0004994869232177734s
# Time taken to Convert the image back to 8-bit (0-255): 0.0005016326904296875s
# Total Time taken to apply custom filter to the image: 1.8120713233947754s
# Processed and saved: cars_filtered\filtered_carsgraz_003.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.002001523971557617s
# Time taken to normalize the 1 image: 0.0004985332489013672s
# Time taken to apply filter to 1 image (Nested Loop): 1.766172170639038s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0005002021789550781s
# Time taken to Convert the image back to 8-bit (0-255): 0.0005009174346923828s
# Total Time taken to apply custom filter to the image: 1.7696733474731445s
# Processed and saved: cars_filtered\filtered_carsgraz_004.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0004992485046386719s
# Time taken to apply Sobel filter to an image: 0.001998424530029297s
# Time taken to normalize the 1 image: 0.0004990100860595703s
# Time taken to apply filter to 1 image (Nested Loop): 1.8109970092773438s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0005035400390625s
# Time taken to Convert the image back to 8-bit (0-255): 0.0005037784576416016s
# Total Time taken to apply custom filter to the image: 1.8155138492584229s
# Processed and saved: cars_filtered\filtered_carsgraz_005.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.0025129318237304688s
# Time taken to normalize the 1 image: 0.0004992485046386719s
# Time taken to apply filter to 1 image (Nested Loop): 1.7879595756530762s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0004980564117431641s
# Time taken to Convert the image back to 8-bit (0-255): 0.0005028247833251953s
# Total Time taken to apply custom filter to the image: 1.7924835681915283s
# Processed and saved: cars_filtered\filtered_carsgraz_006.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.002002239227294922s
# Time taken to normalize the 1 image: 0.0004987716674804688s
# Time taken to apply filter to 1 image (Nested Loop): 1.790210247039795s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0005021095275878906s
# Time taken to Convert the image back to 8-bit (0-255): 0.0s
# Total Time taken to apply custom filter to the image: 1.7942256927490234s
# Processed and saved: cars_filtered\filtered_carsgraz_007.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.0020308494567871094s
# Time taken to normalize the 1 image: 0.00102996826171875s
# Time taken to apply filter to 1 image (Nested Loop): 1.8351342678070068s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0s
# Time taken to Convert the image back to 8-bit (0-255): 0.0005052089691162109s
# Total Time taken to apply custom filter to the image: 1.8397090435028076s
# Processed and saved: cars_filtered\filtered_carsgraz_008.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.002004384994506836s
# Time taken to normalize the 1 image: 0.000499725341796875s
# Time taken to apply filter to 1 image (Nested Loop): 1.762341022491455s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0s
# Time taken to Convert the image back to 8-bit (0-255): 0.0005013942718505859s
# Total Time taken to apply custom filter to the image: 1.766357421875s
# Processed and saved: cars_filtered\filtered_carsgraz_009.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.0019981861114501953s
# Time taken to normalize the 1 image: 0.0005002021789550781s
# Time taken to apply filter to 1 image (Nested Loop): 1.7501459121704102s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0005028247833251953s
# Time taken to Convert the image back to 8-bit (0-255): 0.0004994869232177734s
# Total Time taken to apply custom filter to the image: 1.7536466121673584s
# Processed and saved: cars_filtered\filtered_carsgraz_010.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.002005338668823242s
# Time taken to normalize the 1 image: 0.0004954338073730469s
# Time taken to apply filter to 1 image (Nested Loop): 1.7709956169128418s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0005006790161132812s
# Time taken to Convert the image back to 8-bit (0-255): 0.0005040168762207031s
# Total Time taken to apply custom filter to the image: 1.7750093936920166s
# Processed and saved: cars_filtered\filtered_carsgraz_011.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.002498149871826172s
# Time taken to normalize the 1 image: 0.000499725341796875s
# Time taken to apply filter to 1 image (Nested Loop): 1.7436585426330566s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0005028247833251953s
# Time taken to Convert the image back to 8-bit (0-255): 0.0004963874816894531s
# Total Time taken to apply custom filter to the image: 1.7481622695922852s
# Processed and saved: cars_filtered\filtered_carsgraz_012.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.0020079612731933594s
# Time taken to normalize the 1 image: 0.0004994869232177734s
# Time taken to apply filter to 1 image (Nested Loop): 1.7585537433624268s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0004982948303222656s
# Time taken to Convert the image back to 8-bit (0-255): 0.0005040168762207031s
# Total Time taken to apply custom filter to the image: 1.7625668048858643s
# Processed and saved: cars_filtered\filtered_carsgraz_013.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.002513408660888672s
# Time taken to normalize the 1 image: 0.0009992122650146484s
# Time taken to apply filter to 1 image (Nested Loop): 1.8068315982818604s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0010042190551757812s
# Time taken to Convert the image back to 8-bit (0-255): 0.0005056858062744141s
# Total Time taken to apply custom filter to the image: 1.8123664855957031s
# Processed and saved: cars_filtered\filtered_carsgraz_014.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.003023386001586914s
# Time taken to normalize the 1 image: 0.0004994869232177734s
# Time taken to apply filter to 1 image (Nested Loop): 1.7845613956451416s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0004992485046386719s
# Time taken to Convert the image back to 8-bit (0-255): 0.0s
# Total Time taken to apply custom filter to the image: 1.7895910739898682s
# Processed and saved: cars_filtered\filtered_carsgraz_015.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0004985332489013672s
# Time taken to apply Sobel filter to an image: 0.0020012855529785156s
# Time taken to normalize the 1 image: 0.0004985332489013672s
# Time taken to apply filter to 1 image (Nested Loop): 1.743337869644165s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0005004405975341797s
# Time taken to Convert the image back to 8-bit (0-255): 0.0s
# Total Time taken to apply custom filter to the image: 1.7473373413085938s
# Processed and saved: cars_filtered\filtered_carsgraz_016.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0005009174346923828s
# Time taken to apply Sobel filter to an image: 0.0020093917846679688s
# Time taken to normalize the 1 image: 0.0010006427764892578s
# Time taken to apply filter to 1 image (Nested Loop): 1.7986102104187012s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0s
# Time taken to Convert the image back to 8-bit (0-255): 0.0010077953338623047s
# Total Time taken to apply custom filter to the image: 1.8041458129882812s
# Processed and saved: cars_filtered\filtered_carsgraz_017.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0010077953338623047s
# Time taken to apply Sobel filter to an image: 0.003000974655151367s
# Time taken to normalize the 1 image: 0.000997781753540039s
# Time taken to apply filter to 1 image (Nested Loop): 1.8487918376922607s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0005011558532714844s
# Time taken to Convert the image back to 8-bit (0-255): 0.0004999637603759766s
# Total Time taken to apply custom filter to the image: 1.8553073406219482s
# Processed and saved: cars_filtered\filtered_carsgraz_018.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0005002021789550781s
# Time taken to apply Sobel filter to an image: 0.002001523971557617s
# Time taken to normalize the 1 image: 0.0004985332489013672s
# Time taken to apply filter to 1 image (Nested Loop): 1.8684284687042236s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0004987716674804688s
# Time taken to Convert the image back to 8-bit (0-255): 0.0005016326904296875s
# Total Time taken to apply custom filter to the image: 1.8734376430511475s
# Processed and saved: cars_filtered\filtered_carsgraz_019.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.002501249313354492s
# Time taken to normalize the 1 image: 0.0004975795745849609s
# Time taken to apply filter to 1 image (Nested Loop): 1.8158926963806152s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0004985332489013672s
# Time taken to Convert the image back to 8-bit (0-255): 0.0s
# Total Time taken to apply custom filter to the image: 1.8199026584625244s
# Processed and saved: cars_filtered\filtered_carsgraz_020.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.0029981136322021484s
# Time taken to normalize the 1 image: 0.0010025501251220703s
# Time taken to apply filter to 1 image (Nested Loop): 1.7839488983154297s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0s
# Time taken to Convert the image back to 8-bit (0-255): 0.0004994869232177734s
# Total Time taken to apply custom filter to the image: 1.7894620895385742s
# Processed and saved: cars_filtered\filtered_carsgraz_021.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0005080699920654297s
# Time taken to apply Sobel filter to an image: 0.002508401870727539s
# Time taken to normalize the 1 image: 0.0004985332489013672s
# Time taken to apply filter to 1 image (Nested Loop): 1.769263744354248s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0005009174346923828s
# Time taken to Convert the image back to 8-bit (0-255): 0.0004999637603759766s
# Total Time taken to apply custom filter to the image: 1.7742815017700195s
# Processed and saved: cars_filtered\filtered_carsgraz_022.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.002497434616088867s
# Time taken to normalize the 1 image: 0.0004992485046386719s
# Time taken to apply filter to 1 image (Nested Loop): 1.7787411212921143s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0004994869232177734s
# Time taken to Convert the image back to 8-bit (0-255): 0.0004987716674804688s
# Total Time taken to apply custom filter to the image: 1.7832422256469727s
# Processed and saved: cars_filtered\filtered_carsgraz_023.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.0020322799682617188s
# Time taken to normalize the 1 image: 0.0010120868682861328s
# Time taken to apply filter to 1 image (Nested Loop): 1.8081879615783691s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0004992485046386719s
# Time taken to Convert the image back to 8-bit (0-255): 0.0005011558532714844s
# Total Time taken to apply custom filter to the image: 1.8127527236938477s
# Processed and saved: cars_filtered\filtered_carsgraz_024.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.002501964569091797s
# Time taken to normalize the 1 image: 0.000997304916381836s
# Time taken to apply filter to 1 image (Nested Loop): 1.7697668075561523s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0005009174346923828s
# Time taken to Convert the image back to 8-bit (0-255): 0.0005002021789550781s
# Total Time taken to apply custom filter to the image: 1.7747797966003418s
# Processed and saved: cars_filtered\filtered_carsgraz_025.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.001999378204345703s
# Time taken to normalize the 1 image: 0.0010004043579101562s
# Time taken to apply filter to 1 image (Nested Loop): 1.7749760150909424s
# Time taken to Clip the output to stay in the range [0, 1]: 0.000507354736328125s
# Time taken to Convert the image back to 8-bit (0-255): 0.0004973411560058594s
# Total Time taken to apply custom filter to the image: 1.7789804935455322s
# Processed and saved: cars_filtered\filtered_carsgraz_026.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0004992485046386719s
# Time taken to apply Sobel filter to an image: 0.002008676528930664s
# Time taken to normalize the 1 image: 0.0004982948303222656s
# Time taken to apply filter to 1 image (Nested Loop): 1.7807440757751465s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0005009174346923828s
# Time taken to Convert the image back to 8-bit (0-255): 0.0s
# Total Time taken to apply custom filter to the image: 1.784749984741211s
# Processed and saved: cars_filtered\filtered_carsgraz_027.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.0030150413513183594s
# Time taken to normalize the 1 image: 0.0004975795745849609s
# Time taken to apply filter to 1 image (Nested Loop): 1.7666165828704834s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0010063648223876953s
# Time taken to Convert the image back to 8-bit (0-255): 0.0005054473876953125s
# Total Time taken to apply custom filter to the image: 1.7721500396728516s
# Processed and saved: cars_filtered\filtered_carsgraz_028.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0004971027374267578s
# Time taken to apply Sobel filter to an image: 0.0015020370483398438s
# Time taken to normalize the 1 image: 0.0010066032409667969s
# Time taken to apply filter to 1 image (Nested Loop): 1.7769229412078857s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0004994869232177734s
# Time taken to Convert the image back to 8-bit (0-255): 0.000499725341796875s
# Total Time taken to apply custom filter to the image: 1.7814311981201172s
# Processed and saved: cars_filtered\filtered_carsgraz_029.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.001999378204345703s
# Time taken to normalize the 1 image: 0.001001119613647461s
# Time taken to apply filter to 1 image (Nested Loop): 1.7853577136993408s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0s
# Time taken to Convert the image back to 8-bit (0-255): 0.0005009174346923828s
# Total Time taken to apply custom filter to the image: 1.7898674011230469s
# Processed and saved: cars_filtered\filtered_carsgraz_030.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.000499725341796875s
# Time taken to apply Sobel filter to an image: 0.0019996166229248047s
# Time taken to normalize the 1 image: 0.0004999637603759766s
# Time taken to apply filter to 1 image (Nested Loop): 1.7763373851776123s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0005009174346923828s
# Time taken to Convert the image back to 8-bit (0-255): 0.0004975795745849609s
# Total Time taken to apply custom filter to the image: 1.7803351879119873s
# Processed and saved: cars_filtered\filtered_carsgraz_031.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.0030145645141601562s
# Time taken to normalize the 1 image: 0.00099945068359375s
# Time taken to apply filter to 1 image (Nested Loop): 1.7929279804229736s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0005013942718505859s
# Time taken to Convert the image back to 8-bit (0-255): 0.0s
# Total Time taken to apply custom filter to the image: 1.7984557151794434s
# Processed and saved: cars_filtered\filtered_carsgraz_032.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.002500772476196289s
# Time taken to normalize the 1 image: 0.0004999637603759766s
# Time taken to apply filter to 1 image (Nested Loop): 1.818634271621704s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0004994869232177734s
# Time taken to Convert the image back to 8-bit (0-255): 0.0s
# Total Time taken to apply custom filter to the image: 1.8226423263549805s
# Processed and saved: cars_filtered\filtered_carsgraz_033.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.0019989013671875s
# Time taken to normalize the 1 image: 0.0005002021789550781s
# Time taken to apply filter to 1 image (Nested Loop): 1.790175199508667s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0004992485046386719s
# Time taken to Convert the image back to 8-bit (0-255): 0.0005013942718505859s
# Total Time taken to apply custom filter to the image: 1.7936749458312988s
# Processed and saved: cars_filtered\filtered_carsgraz_034.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.0019991397857666016s
# Time taken to normalize the 1 image: 0.0009996891021728516s
# Time taken to apply filter to 1 image (Nested Loop): 1.791701316833496s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0005006790161132812s
# Time taken to Convert the image back to 8-bit (0-255): 0.0004994869232177734s
# Total Time taken to apply custom filter to the image: 1.7957003116607666s
# Processed and saved: cars_filtered\filtered_carsgraz_035.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.0030128955841064453s
# Time taken to normalize the 1 image: 0.0004968643188476562s
# Time taken to apply filter to 1 image (Nested Loop): 1.7814440727233887s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0s
# Time taken to Convert the image back to 8-bit (0-255): 0.000499725341796875s
# Total Time taken to apply custom filter to the image: 1.7864696979522705s
# Processed and saved: cars_filtered\filtered_carsgraz_036.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.0019998550415039062s
# Time taken to normalize the 1 image: 0.0010025501251220703s
# Time taken to apply filter to 1 image (Nested Loop): 1.821655511856079s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0s
# Time taken to Convert the image back to 8-bit (0-255): 0.0004978179931640625s
# Total Time taken to apply custom filter to the image: 1.8261635303497314s
# Processed and saved: cars_filtered\filtered_carsgraz_037.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.0019986629486083984s
# Time taken to normalize the 1 image: 0.0004994869232177734s
# Time taken to apply filter to 1 image (Nested Loop): 1.7818994522094727s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0010001659393310547s
# Time taken to Convert the image back to 8-bit (0-255): 0.0s
# Total Time taken to apply custom filter to the image: 1.7863988876342773s
# Processed and saved: cars_filtered\filtered_carsgraz_038.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.002012014389038086s
# Time taken to normalize the 1 image: 0.0004994869232177734s
# Time taken to apply filter to 1 image (Nested Loop): 1.752119541168213s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0004999637603759766s
# Time taken to Convert the image back to 8-bit (0-255): 0.0s
# Total Time taken to apply custom filter to the image: 1.755643606185913s
# Processed and saved: cars_filtered\filtered_carsgraz_039.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.002000093460083008s
# Time taken to normalize the 1 image: 0.0005013942718505859s
# Time taken to apply filter to 1 image (Nested Loop): 1.7496585845947266s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0005006790161132812s
# Time taken to Convert the image back to 8-bit (0-255): 0.0005006790161132812s
# Total Time taken to apply custom filter to the image: 1.753662347793579s
# Processed and saved: cars_filtered\filtered_carsgraz_040.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.0025000572204589844s
# Time taken to normalize the 1 image: 0.0004999637603759766s
# Time taken to apply filter to 1 image (Nested Loop): 1.7654564380645752s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0s
# Time taken to Convert the image back to 8-bit (0-255): 0.0005004405975341797s
# Total Time taken to apply custom filter to the image: 1.7699613571166992s
# Processed and saved: cars_filtered\filtered_carsgraz_041.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.002058267593383789s
# Time taken to normalize the 1 image: 0.0010120868682861328s
# Time taken to apply filter to 1 image (Nested Loop): 1.7657570838928223s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0005011558532714844s
# Time taken to Convert the image back to 8-bit (0-255): 0.0s
# Total Time taken to apply custom filter to the image: 1.7698345184326172s
# Processed and saved: cars_filtered\filtered_carsgraz_042.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0005049705505371094s
# Time taken to apply Sobel filter to an image: 0.002000570297241211s
# Time taken to normalize the 1 image: 0.0004985332489013672s
# Time taken to apply filter to 1 image (Nested Loop): 1.7508673667907715s
# Time taken to Clip the output to stay in the range [0, 1]: 0.001004934310913086s
# Time taken to Convert the image back to 8-bit (0-255): 0.0005061626434326172s
# Total Time taken to apply custom filter to the image: 1.755887508392334s
# Processed and saved: cars_filtered\filtered_carsgraz_043.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.0020105838775634766s
# Time taken to normalize the 1 image: 0.0010018348693847656s
# Time taken to apply filter to 1 image (Nested Loop): 1.806114673614502s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0s
# Time taken to Convert the image back to 8-bit (0-255): 0.0005002021789550781s
# Total Time taken to apply custom filter to the image: 1.8106346130371094s
# Processed and saved: cars_filtered\filtered_carsgraz_044.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.0019991397857666016s
# Time taken to normalize the 1 image: 0.0005013942718505859s
# Time taken to apply filter to 1 image (Nested Loop): 1.7593533992767334s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0s
# Time taken to Convert the image back to 8-bit (0-255): 0.0s
# Total Time taken to apply custom filter to the image: 1.763873815536499s
# Processed and saved: cars_filtered\filtered_carsgraz_045.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.0020017623901367188s
# Time taken to normalize the 1 image: 0.0010035037994384766s
# Time taken to apply filter to 1 image (Nested Loop): 1.753829002380371s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0005011558532714844s
# Time taken to Convert the image back to 8-bit (0-255): 0.0005004405975341797s
# Total Time taken to apply custom filter to the image: 1.757835865020752s
# Processed and saved: cars_filtered\filtered_carsgraz_046.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.001997709274291992s
# Time taken to normalize the 1 image: 0.0010013580322265625s
# Time taken to apply filter to 1 image (Nested Loop): 1.7434303760528564s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0s
# Time taken to Convert the image back to 8-bit (0-255): 0.0s
# Total Time taken to apply custom filter to the image: 1.7474339008331299s
# Processed and saved: cars_filtered\filtered_carsgraz_047.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0004980564117431641s
# Time taken to apply Sobel filter to an image: 0.0019998550415039062s
# Time taken to normalize the 1 image: 0.0s
# Time taken to apply filter to 1 image (Nested Loop): 1.744624137878418s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0005018711090087891s
# Time taken to Convert the image back to 8-bit (0-255): 0.0004987716674804688s
# Total Time taken to apply custom filter to the image: 1.748626470565796s
# Processed and saved: cars_filtered\filtered_carsgraz_048.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.002000093460083008s
# Time taken to normalize the 1 image: 0.0004987716674804688s
# Time taken to apply filter to 1 image (Nested Loop): 1.745445728302002s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0005075931549072266s
# Time taken to Convert the image back to 8-bit (0-255): 0.0005021095275878906s
# Total Time taken to apply custom filter to the image: 1.749457597732544s
# Processed and saved: cars_filtered\filtered_carsgraz_049.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.002000570297241211s
# Time taken to normalize the 1 image: 0.0005066394805908203s
# Time taken to apply filter to 1 image (Nested Loop): 1.743844985961914s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0004994869232177734s
# Time taken to Convert the image back to 8-bit (0-255): 0.0s
# Total Time taken to apply custom filter to the image: 1.7473623752593994s
# Processed and saved: cars_filtered\filtered_carsgraz_050.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.0019986629486083984s
# Time taken to normalize the 1 image: 0.0004978179931640625s
# Time taken to apply filter to 1 image (Nested Loop): 1.7757079601287842s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0010085105895996094s
# Time taken to Convert the image back to 8-bit (0-255): 0.0010101795196533203s
# Total Time taken to apply custom filter to the image: 1.7807259559631348s
# Processed and saved: cars_filtered\filtered_carsgraz_051.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0004994869232177734s
# Time taken to apply Sobel filter to an image: 0.0020067691802978516s
# Time taken to normalize the 1 image: 0.0009992122650146484s
# Time taken to apply filter to 1 image (Nested Loop): 1.8993682861328125s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0005011558532714844s
# Time taken to Convert the image back to 8-bit (0-255): 0.0s
# Total Time taken to apply custom filter to the image: 1.90437650680542s
# Processed and saved: cars_filtered\filtered_carsgraz_052.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.0020024776458740234s
# Time taken to normalize the 1 image: 0.0004982948303222656s
# Time taken to apply filter to 1 image (Nested Loop): 1.8066315650939941s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0005033016204833984s
# Time taken to Convert the image back to 8-bit (0-255): 0.0004987716674804688s
# Total Time taken to apply custom filter to the image: 1.811140537261963s
# Processed and saved: cars_filtered\filtered_carsgraz_053.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.00301361083984375s
# Time taken to normalize the 1 image: 0.0005002021789550781s
# Time taken to apply filter to 1 image (Nested Loop): 1.7838339805603027s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0005033016204833984s
# Time taken to Convert the image back to 8-bit (0-255): 0.0004966259002685547s
# Total Time taken to apply custom filter to the image: 1.7888514995574951s
# Processed and saved: cars_filtered\filtered_carsgraz_054.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0004982948303222656s
# Time taken to apply Sobel filter to an image: 0.0020012855529785156s
# Time taken to normalize the 1 image: 0.0004968643188476562s
# Time taken to apply filter to 1 image (Nested Loop): 1.8109650611877441s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0010058879852294922s
# Time taken to Convert the image back to 8-bit (0-255): 0.0005059242248535156s
# Total Time taken to apply custom filter to the image: 1.8159842491149902s
# Processed and saved: cars_filtered\filtered_carsgraz_055.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.0019981861114501953s
# Time taken to normalize the 1 image: 0.000499725341796875s
# Time taken to apply filter to 1 image (Nested Loop): 1.7599546909332275s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0s
# Time taken to Convert the image back to 8-bit (0-255): 0.0010066032409667969s
# Total Time taken to apply custom filter to the image: 1.7639720439910889s
# Processed and saved: cars_filtered\filtered_carsgraz_056.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.0015001296997070312s
# Time taken to normalize the 1 image: 0.001508474349975586s
# Time taken to apply filter to 1 image (Nested Loop): 1.7863061428070068s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0005021095275878906s
# Time taken to Convert the image back to 8-bit (0-255): 0.0004999637603759766s
# Total Time taken to apply custom filter to the image: 1.7903168201446533s
# Processed and saved: cars_filtered\filtered_carsgraz_057.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0004990100860595703s
# Time taken to apply Sobel filter to an image: 0.002003908157348633s
# Time taken to normalize the 1 image: 0.0004947185516357422s
# Time taken to apply filter to 1 image (Nested Loop): 1.772780179977417s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0004971027374267578s
# Time taken to Convert the image back to 8-bit (0-255): 0.0s
# Total Time taken to apply custom filter to the image: 1.7772808074951172s
# Processed and saved: cars_filtered\filtered_carsgraz_058.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.002511262893676758s
# Time taken to normalize the 1 image: 0.0009982585906982422s
# Time taken to apply filter to 1 image (Nested Loop): 1.7828459739685059s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0004978179931640625s
# Time taken to Convert the image back to 8-bit (0-255): 0.0s
# Total Time taken to apply custom filter to the image: 1.786853313446045s
# Processed and saved: cars_filtered\filtered_carsgraz_059.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.0025110244750976562s
# Time taken to normalize the 1 image: 0.0s
# Time taken to apply filter to 1 image (Nested Loop): 1.853977918624878s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0005023479461669922s
# Time taken to Convert the image back to 8-bit (0-255): 0.0004985332489013672s
# Total Time taken to apply custom filter to the image: 1.8579907417297363s
# Processed and saved: cars_filtered\filtered_carsgraz_060.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.0029981136322021484s
# Time taken to normalize the 1 image: 0.0005011558532714844s
# Time taken to apply filter to 1 image (Nested Loop): 1.8829264640808105s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0005028247833251953s
# Time taken to Convert the image back to 8-bit (0-255): 0.0004987716674804688s
# Total Time taken to apply custom filter to the image: 1.8874273300170898s
# Processed and saved: cars_filtered\filtered_carsgraz_061.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.0030112266540527344s
# Time taken to normalize the 1 image: 0.000499725341796875s
# Time taken to apply filter to 1 image (Nested Loop): 1.7548725605010986s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0005013942718505859s
# Time taken to Convert the image back to 8-bit (0-255): 0.0005013942718505859s
# Total Time taken to apply custom filter to the image: 1.7598936557769775s
# Processed and saved: cars_filtered\filtered_carsgraz_062.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.002502918243408203s
# Time taken to normalize the 1 image: 0.0004980564117431641s
# Time taken to apply filter to 1 image (Nested Loop): 1.7755029201507568s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0010023117065429688s
# Time taken to Convert the image back to 8-bit (0-255): 0.0005078315734863281s
# Total Time taken to apply custom filter to the image: 1.7805194854736328s
# Processed and saved: cars_filtered\filtered_carsgraz_063.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.0030083656311035156s
# Time taken to normalize the 1 image: 0.0005002021789550781s
# Time taken to apply filter to 1 image (Nested Loop): 1.7639803886413574s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0005066394805908203s
# Time taken to Convert the image back to 8-bit (0-255): 0.0004956722259521484s
# Total Time taken to apply custom filter to the image: 1.768491268157959s
# Processed and saved: cars_filtered\filtered_carsgraz_064.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.0019974708557128906s
# Time taken to normalize the 1 image: 0.0005009174346923828s
# Time taken to apply filter to 1 image (Nested Loop): 1.7760546207427979s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0005025863647460938s
# Time taken to Convert the image back to 8-bit (0-255): 0.0s
# Total Time taken to apply custom filter to the image: 1.7800531387329102s
# Processed and saved: cars_filtered\filtered_carsgraz_065.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.002002716064453125s
# Time taken to normalize the 1 image: 0.0009992122650146484s
# Time taken to apply filter to 1 image (Nested Loop): 1.791905403137207s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0005023479461669922s
# Time taken to Convert the image back to 8-bit (0-255): 0.0004985332489013672s
# Total Time taken to apply custom filter to the image: 1.796410322189331s
# Processed and saved: cars_filtered\filtered_carsgraz_066.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.0020029544830322266s
# Time taken to normalize the 1 image: 0.0005028247833251953s
# Time taken to apply filter to 1 image (Nested Loop): 1.7982306480407715s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0005033016204833984s
# Time taken to Convert the image back to 8-bit (0-255): 0.0004985332489013672s
# Total Time taken to apply custom filter to the image: 1.8017382621765137s
# Processed and saved: cars_filtered\filtered_carsgraz_067.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.001997232437133789s
# Time taken to normalize the 1 image: 0.0010004043579101562s
# Time taken to apply filter to 1 image (Nested Loop): 1.7942657470703125s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0005035400390625s
# Time taken to Convert the image back to 8-bit (0-255): 0.0004980564117431641s
# Total Time taken to apply custom filter to the image: 1.7987699508666992s
# Processed and saved: cars_filtered\filtered_carsgraz_068.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.003018617630004883s
# Time taken to normalize the 1 image: 0.0009999275207519531s
# Time taken to apply filter to 1 image (Nested Loop): 1.7953364849090576s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0005006790161132812s
# Time taken to Convert the image back to 8-bit (0-255): 0.0s
# Total Time taken to apply custom filter to the image: 1.7998557090759277s
# Processed and saved: cars_filtered\filtered_carsgraz_069.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.002001523971557617s
# Time taken to normalize the 1 image: 0.0004980564117431641s
# Time taken to apply filter to 1 image (Nested Loop): 1.769784927368164s
# Time taken to Clip the output to stay in the range [0, 1]: 0.001007080078125s
# Time taken to Convert the image back to 8-bit (0-255): 0.0005087852478027344s
# Total Time taken to apply custom filter to the image: 1.7738003730773926s
# Processed and saved: cars_filtered\filtered_carsgraz_070.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.0025017261505126953s
# Time taken to normalize the 1 image: 0.0004990100860595703s
# Time taken to apply filter to 1 image (Nested Loop): 1.7855291366577148s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0s
# Time taken to Convert the image back to 8-bit (0-255): 0.0004990100860595703s
# Total Time taken to apply custom filter to the image: 1.7900311946868896s
# Processed and saved: cars_filtered\filtered_carsgraz_071.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.001998424530029297s
# Time taken to normalize the 1 image: 0.000499725341796875s
# Time taken to apply filter to 1 image (Nested Loop): 1.7444384098052979s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0005071163177490234s
# Time taken to Convert the image back to 8-bit (0-255): 0.0005002021789550781s
# Total Time taken to apply custom filter to the image: 1.748460054397583s
# Processed and saved: cars_filtered\filtered_carsgraz_072.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.0020563602447509766s
# Time taken to normalize the 1 image: 0.0005064010620117188s
# Time taken to apply filter to 1 image (Nested Loop): 1.7474582195281982s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0005004405975341797s
# Time taken to Convert the image back to 8-bit (0-255): 0.0s
# Total Time taken to apply custom filter to the image: 1.751021146774292s
# Processed and saved: cars_filtered\filtered_carsgraz_073.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.002004384994506836s
# Time taken to normalize the 1 image: 0.0009984970092773438s
# Time taken to apply filter to 1 image (Nested Loop): 1.7654955387115479s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0s
# Time taken to Convert the image back to 8-bit (0-255): 0.0005047321319580078s
# Total Time taken to apply custom filter to the image: 1.7700142860412598s
# Processed and saved: cars_filtered\filtered_carsgraz_074.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.0019986629486083984s
# Time taken to normalize the 1 image: 0.0005042552947998047s
# Time taken to apply filter to 1 image (Nested Loop): 1.764301061630249s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0s
# Time taken to Convert the image back to 8-bit (0-255): 0.0004973411560058594s
# Total Time taken to apply custom filter to the image: 1.7683160305023193s
# Processed and saved: cars_filtered\filtered_carsgraz_075.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.0020096302032470703s
# Time taken to normalize the 1 image: 0.0005044937133789062s
# Time taken to apply filter to 1 image (Nested Loop): 1.7646853923797607s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0005006790161132812s
# Time taken to Convert the image back to 8-bit (0-255): 0.0s
# Total Time taken to apply custom filter to the image: 1.7682044506072998s
# Processed and saved: cars_filtered\filtered_carsgraz_076.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0004990100860595703s
# Time taken to apply Sobel filter to an image: 0.002000093460083008s
# Time taken to normalize the 1 image: 0.0005009174346923828s
# Time taken to apply filter to 1 image (Nested Loop): 1.742262601852417s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0010066032409667969s
# Time taken to Convert the image back to 8-bit (0-255): 0.0005075931549072266s
# Total Time taken to apply custom filter to the image: 1.747281789779663s
# Processed and saved: cars_filtered\filtered_carsgraz_077.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.0014998912811279297s
# Time taken to normalize the 1 image: 0.0010051727294921875s
# Time taken to apply filter to 1 image (Nested Loop): 1.819143533706665s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0s
# Time taken to Convert the image back to 8-bit (0-255): 0.001005411148071289s
# Total Time taken to apply custom filter to the image: 1.8231654167175293s
# Processed and saved: cars_filtered\filtered_carsgraz_078.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.002521038055419922s
# Time taken to normalize the 1 image: 0.0009951591491699219s
# Time taken to apply filter to 1 image (Nested Loop): 1.7553520202636719s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0005016326904296875s
# Time taken to Convert the image back to 8-bit (0-255): 0.0s
# Total Time taken to apply custom filter to the image: 1.759882926940918s
# Processed and saved: cars_filtered\filtered_carsgraz_079.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.0020020008087158203s
# Time taken to normalize the 1 image: 0.0004987716674804688s
# Time taken to apply filter to 1 image (Nested Loop): 1.768644094467163s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0005009174346923828s
# Time taken to Convert the image back to 8-bit (0-255): 0.0005042552947998047s
# Total Time taken to apply custom filter to the image: 1.7726569175720215s
# Processed and saved: cars_filtered\filtered_carsgraz_080.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.0019986629486083984s
# Time taken to normalize the 1 image: 0.0005004405975341797s
# Time taken to apply filter to 1 image (Nested Loop): 1.769862413406372s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0005030632019042969s
# Time taken to Convert the image back to 8-bit (0-255): 0.0004999637603759766s
# Total Time taken to apply custom filter to the image: 1.7743761539459229s
# Processed and saved: cars_filtered\filtered_carsgraz_081.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.0020024776458740234s
# Time taken to normalize the 1 image: 0.0004980564117431641s
# Time taken to apply filter to 1 image (Nested Loop): 1.8013646602630615s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0s
# Time taken to Convert the image back to 8-bit (0-255): 0.0s
# Total Time taken to apply custom filter to the image: 1.804877758026123s
# Processed and saved: cars_filtered\filtered_carsgraz_082.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.0030736923217773438s
# Time taken to normalize the 1 image: 0.0010061264038085938s
# Time taken to apply filter to 1 image (Nested Loop): 1.8547823429107666s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0004994869232177734s
# Time taken to Convert the image back to 8-bit (0-255): 0.0s
# Total Time taken to apply custom filter to the image: 1.8598601818084717s
# Processed and saved: cars_filtered\filtered_carsgraz_083.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.0020003318786621094s
# Time taken to normalize the 1 image: 0.0009989738464355469s
# Time taken to apply filter to 1 image (Nested Loop): 1.7638840675354004s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0005042552947998047s
# Time taken to Convert the image back to 8-bit (0-255): 0.0004968643188476562s
# Total Time taken to apply custom filter to the image: 1.768401861190796s
# Processed and saved: cars_filtered\filtered_carsgraz_084.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.002517223358154297s
# Time taken to normalize the 1 image: 0.0004973411560058594s
# Time taken to apply filter to 1 image (Nested Loop): 1.8049559593200684s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0s
# Time taken to Convert the image back to 8-bit (0-255): 0.0005028247833251953s
# Total Time taken to apply custom filter to the image: 1.8094844818115234s
# Processed and saved: cars_filtered\filtered_carsgraz_085.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.00251007080078125s
# Time taken to normalize the 1 image: 0.0010020732879638672s
# Time taken to apply filter to 1 image (Nested Loop): 1.8205351829528809s
# Time taken to Clip the output to stay in the range [0, 1]: 0.000499725341796875s
# Time taken to Convert the image back to 8-bit (0-255): 0.0s
# Total Time taken to apply custom filter to the image: 1.825047492980957s
# Processed and saved: cars_filtered\filtered_carsgraz_086.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.0019991397857666016s
# Time taken to normalize the 1 image: 0.0004994869232177734s
# Time taken to apply filter to 1 image (Nested Loop): 1.8145220279693604s
# Time taken to Clip the output to stay in the range [0, 1]: 0.000499725341796875s
# Time taken to Convert the image back to 8-bit (0-255): 0.000499725341796875s
# Total Time taken to apply custom filter to the image: 1.8185203075408936s
# Processed and saved: cars_filtered\filtered_carsgraz_087.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.0025055408477783203s
# Time taken to normalize the 1 image: 0.0004994869232177734s
# Time taken to apply filter to 1 image (Nested Loop): 1.7686872482299805s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0004999637603759766s
# Time taken to Convert the image back to 8-bit (0-255): 0.0004987716674804688s
# Total Time taken to apply custom filter to the image: 1.7737045288085938s
# Processed and saved: cars_filtered\filtered_carsgraz_088.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0004978179931640625s
# Time taken to apply Sobel filter to an image: 0.0019998550415039062s
# ...
# Total Time taken to apply custom filter to the image: 1.7347590923309326s
# Processed and saved: cars_filtered\filtered_carsgraz_171.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.002023458480834961s
# Time taken to normalize the 1 image: 0.0010197162628173828s
# Time taken to apply filter to 1 image (Nested Loop): 1.7383012771606445s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0005004405975341797s
# Time taken to Convert the image back to 8-bit (0-255): 0.0s
# Total Time taken to apply custom filter to the image: 1.7423501014709473s
# Processed and saved: cars_filtered\filtered_carsgraz_172.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.0025005340576171875s
# Time taken to normalize the 1 image: 0.0004985332489013672s
# Time taken to apply filter to 1 image (Nested Loop): 1.7464056015014648s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0005042552947998047s
# Time taken to Convert the image back to 8-bit (0-255): 0.0005002021789550781s
# Total Time taken to apply custom filter to the image: 1.7509188652038574s
# Processed and saved: cars_filtered\filtered_carsgraz_173.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.0020034313201904297s
# Time taken to normalize the 1 image: 0.0005042552947998047s
# Time taken to apply filter to 1 image (Nested Loop): 1.7411174774169922s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0004982948303222656s
# Time taken to Convert the image back to 8-bit (0-255): 0.0004990100860595703s
# Total Time taken to apply custom filter to the image: 1.7446224689483643s
# Processed and saved: cars_filtered\filtered_carsgraz_174.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.0023500919342041016s
# Time taken to normalize the 1 image: 0.0s
# Time taken to apply filter to 1 image (Nested Loop): 1.7398509979248047s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0s
# Time taken to Convert the image back to 8-bit (0-255): 0.0005006790161132812s
# Total Time taken to apply custom filter to the image: 1.7437164783477783s
# Processed and saved: cars_filtered\filtered_carsgraz_175.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.00200653076171875s
# Time taken to normalize the 1 image: 0.0005009174346923828s
# Time taken to apply filter to 1 image (Nested Loop): 1.7364137172698975s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0s
# Time taken to Convert the image back to 8-bit (0-255): 0.0s
# Total Time taken to apply custom filter to the image: 1.7399318218231201s
# Processed and saved: cars_filtered\filtered_carsgraz_176.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.0019986629486083984s
# Time taken to normalize the 1 image: 0.0s
# Time taken to apply filter to 1 image (Nested Loop): 1.7503070831298828s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0s
# Time taken to Convert the image back to 8-bit (0-255): 0.0010044574737548828s
# Total Time taken to apply custom filter to the image: 1.75382661819458s
# Processed and saved: cars_filtered\filtered_carsgraz_177.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.002002716064453125s
# Time taken to normalize the 1 image: 0.0s
# Time taken to apply filter to 1 image (Nested Loop): 1.732572317123413s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0005018711090087891s
# Time taken to Convert the image back to 8-bit (0-255): 0.0004999637603759766s
# Total Time taken to apply custom filter to the image: 1.7360894680023193s
# Processed and saved: cars_filtered\filtered_carsgraz_178.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.002005338668823242s
# Time taken to normalize the 1 image: 0.0005018711090087891s
# Time taken to apply filter to 1 image (Nested Loop): 1.7656049728393555s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0s
# Time taken to Convert the image back to 8-bit (0-255): 0.0010051727294921875s
# Total Time taken to apply custom filter to the image: 1.770634651184082s
# Processed and saved: cars_filtered\filtered_carsgraz_179.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0005004405975341797s
# Time taken to apply Sobel filter to an image: 0.0014967918395996094s
# Time taken to normalize the 1 image: 0.0010030269622802734s
# Time taken to apply filter to 1 image (Nested Loop): 1.7572996616363525s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0005028247833251953s
# Time taken to Convert the image back to 8-bit (0-255): 0.0005009174346923828s
# Total Time taken to apply custom filter to the image: 1.7618119716644287s
# Processed and saved: cars_filtered\filtered_carsgraz_180.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.001999378204345703s
# Time taken to normalize the 1 image: 0.0004990100860595703s
# Time taken to apply filter to 1 image (Nested Loop): 1.7342638969421387s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0s
# Time taken to Convert the image back to 8-bit (0-255): 0.0s
# Total Time taken to apply custom filter to the image: 1.7382752895355225s
# Processed and saved: cars_filtered\filtered_carsgraz_181.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.0020041465759277344s
# Time taken to normalize the 1 image: 0.0005002021789550781s
# Time taken to apply filter to 1 image (Nested Loop): 1.746246576309204s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0010035037994384766s
# Time taken to Convert the image back to 8-bit (0-255): 0.0005052089691162109s
# Total Time taken to apply custom filter to the image: 1.750762701034546s
# Processed and saved: cars_filtered\filtered_carsgraz_182.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0005011558532714844s
# Time taken to apply Sobel filter to an image: 0.0020008087158203125s
# Time taken to normalize the 1 image: 0.0005040168762207031s
# Time taken to apply filter to 1 image (Nested Loop): 1.7382957935333252s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0s
# Time taken to Convert the image back to 8-bit (0-255): 0.001005411148071289s
# Total Time taken to apply custom filter to the image: 1.7428243160247803s
# Processed and saved: cars_filtered\filtered_carsgraz_183.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.0019998550415039062s
# Time taken to normalize the 1 image: 0.0s
# Time taken to apply filter to 1 image (Nested Loop): 1.744286298751831s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0s
# Time taken to Convert the image back to 8-bit (0-255): 0.0005002021789550781s
# Total Time taken to apply custom filter to the image: 1.7477872371673584s
# Processed and saved: cars_filtered\filtered_carsgraz_184.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0005037784576416016s
# Time taken to apply Sobel filter to an image: 0.0019998550415039062s
# Time taken to normalize the 1 image: 0.0004994869232177734s
# Time taken to apply filter to 1 image (Nested Loop): 1.7448790073394775s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0010061264038085938s
# Time taken to Convert the image back to 8-bit (0-255): 0.0005075931549072266s
# Total Time taken to apply custom filter to the image: 1.7499096393585205s
# Processed and saved: cars_filtered\filtered_carsgraz_185.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.0015010833740234375s
# Time taken to normalize the 1 image: 0.0010066032409667969s
# Time taken to apply filter to 1 image (Nested Loop): 1.7313780784606934s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0005006790161132812s
# Time taken to Convert the image back to 8-bit (0-255): 0.0s
# Total Time taken to apply custom filter to the image: 1.73588228225708s
# Processed and saved: cars_filtered\filtered_carsgraz_186.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.002432107925415039s
# Time taken to normalize the 1 image: 0.0010213851928710938s
# Time taken to apply filter to 1 image (Nested Loop): 1.757291316986084s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0005006790161132812s
# Time taken to Convert the image back to 8-bit (0-255): 0.0s
# Total Time taken to apply custom filter to the image: 1.762357473373413s
# Processed and saved: cars_filtered\filtered_carsgraz_187.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.002505064010620117s
# Time taken to normalize the 1 image: 0.0006022453308105469s
# Time taken to apply filter to 1 image (Nested Loop): 1.7343323230743408s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0005004405975341797s
# Time taken to Convert the image back to 8-bit (0-255): 0.0005004405975341797s
# Total Time taken to apply custom filter to the image: 1.7384405136108398s
# Processed and saved: cars_filtered\filtered_carsgraz_188.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.001998424530029297s
# Time taken to normalize the 1 image: 0.001001119613647461s
# Time taken to apply filter to 1 image (Nested Loop): 1.7292110919952393s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0004994869232177734s
# Time taken to Convert the image back to 8-bit (0-255): 0.0005004405975341797s
# Total Time taken to apply custom filter to the image: 1.7337169647216797s
# Processed and saved: cars_filtered\filtered_carsgraz_189.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.0024995803833007812s
# Time taken to normalize the 1 image: 0.0004994869232177734s
# Time taken to apply filter to 1 image (Nested Loop): 1.7415645122528076s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0005023479461669922s
# Time taken to Convert the image back to 8-bit (0-255): 0.0s
# Total Time taken to apply custom filter to the image: 1.74556565284729s
# Processed and saved: cars_filtered\filtered_carsgraz_190.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.0019979476928710938s
# Time taken to normalize the 1 image: 0.000499725341796875s
# Time taken to apply filter to 1 image (Nested Loop): 1.7438740730285645s
# Time taken to Clip the output to stay in the range [0, 1]: 0.000507354736328125s
# Time taken to Convert the image back to 8-bit (0-255): 0.0004975795745849609s
# Total Time taken to apply custom filter to the image: 1.7478809356689453s
# Processed and saved: cars_filtered\filtered_carsgraz_191.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.0014979839324951172s
# Time taken to normalize the 1 image: 0.0010080337524414062s
# Time taken to apply filter to 1 image (Nested Loop): 1.7387573719024658s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0004961490631103516s
# Time taken to Convert the image back to 8-bit (0-255): 0.0s
# Total Time taken to apply custom filter to the image: 1.7417595386505127s
# Processed and saved: cars_filtered\filtered_carsgraz_192.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.0019981861114501953s
# Time taken to normalize the 1 image: 0.0s
# Time taken to apply filter to 1 image (Nested Loop): 1.7334098815917969s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0005011558532714844s
# Time taken to Convert the image back to 8-bit (0-255): 0.0005004405975341797s
# Total Time taken to apply custom filter to the image: 1.7369153499603271s
# Processed and saved: cars_filtered\filtered_carsgraz_193.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.001007080078125s
# Time taken to apply Sobel filter to an image: 0.0020067691802978516s
# Time taken to normalize the 1 image: 0.0004980564117431641s
# Time taken to apply filter to 1 image (Nested Loop): 1.7329299449920654s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0005002021789550781s
# Time taken to Convert the image back to 8-bit (0-255): 0.0004992485046386719s
# Total Time taken to apply custom filter to the image: 1.7379510402679443s
# Processed and saved: cars_filtered\filtered_carsgraz_194.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0004994869232177734s
# Time taken to apply Sobel filter to an image: 0.0019996166229248047s
# Time taken to normalize the 1 image: 0.0005002021789550781s
# Time taken to apply filter to 1 image (Nested Loop): 1.7342336177825928s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0005021095275878906s
# Time taken to Convert the image back to 8-bit (0-255): 0.0004975795745849609s
# Total Time taken to apply custom filter to the image: 1.7387325763702393s
# Processed and saved: cars_filtered\filtered_carsgraz_195.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.0020024776458740234s
# Time taken to normalize the 1 image: 0.0004999637603759766s
# Time taken to apply filter to 1 image (Nested Loop): 1.7437248229980469s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0005009174346923828s
# Time taken to Convert the image back to 8-bit (0-255): 0.0004994869232177734s
# Total Time taken to apply custom filter to the image: 1.7482385635375977s
# Processed and saved: cars_filtered\filtered_carsgraz_196.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.0019979476928710938s
# Time taken to normalize the 1 image: 0.0005009174346923828s
# Time taken to apply filter to 1 image (Nested Loop): 1.7562942504882812s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0005040168762207031s
# Time taken to Convert the image back to 8-bit (0-255): 0.0s
# Total Time taken to apply custom filter to the image: 1.7602930068969727s
# Processed and saved: cars_filtered\filtered_carsgraz_197.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.002496480941772461s
# Time taken to normalize the 1 image: 0.000499725341796875s
# Time taken to apply filter to 1 image (Nested Loop): 1.752601146697998s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0005013942718505859s
# Time taken to Convert the image back to 8-bit (0-255): 0.0005004405975341797s
# Total Time taken to apply custom filter to the image: 1.7571134567260742s
# Processed and saved: cars_filtered\filtered_carsgraz_198.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.0019998550415039062s
# Time taken to normalize the 1 image: 0.0005030632019042969s
# Time taken to apply filter to 1 image (Nested Loop): 1.7410526275634766s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0005013942718505859s
# Time taken to Convert the image back to 8-bit (0-255): 0.0s
# Total Time taken to apply custom filter to the image: 1.7450687885284424s
# Processed and saved: cars_filtered\filtered_carsgraz_199.bmp
#
#
# Time taken to apply Gaussian Blur to an image: 0.0s
# Time taken to apply Sobel filter to an image: 0.002000093460083008s
# Time taken to normalize the 1 image: 0.0004999637603759766s
# Time taken to apply filter to 1 image (Nested Loop): 1.7344303131103516s
# Time taken to Clip the output to stay in the range [0, 1]: 0.0005013942718505859s
# Time taken to Convert the image back to 8-bit (0-255): 0.0005004405975341797s
# Total Time taken to apply custom filter to the image: 1.738433599472046s
# Processed and saved: cars_filtered\filtered_carsgraz_200.bmp
#
#
# Total number of processed images: 200
# Total number of prcoessed rows: 61440000
# Total time taken by the execution of this code sequentially for all images: 355.1749095916748s

# %%
from multiprocessing import cpu_count

logical_cores = cpu_count()
print(f"Number of logical cores: {logical_cores}")
# Out:
# Number of logical cores: 16
